# %% [markdown]
# #### Step1: Change the first frame folder to 0000

# %% [markdown]
# #### Step2: Rename channels

# %%
import os
import re

main_folder = "/Users/xinyicai/Desktop/to_do/20251201_ExRai_Snrk_KO_TIFF/Mouse3"

channel_map = {
    "C001": "ch1",
    "C002": "ch3",
    "C003": "ch2"
}

for subfolder_name in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder_name)

    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder_name}")

        for filename in os.listdir(subfolder_path):
            if not filename.lower().endswith(".tif"):
                continue

            old_path = os.path.join(subfolder_path, filename)

            # Match: prefix + optional _ or - + C001Z001
            match = re.match(r"(.*?)[_-]?(C00[123])Z(\d+)\.tif", filename)
            if not match:
                print(f"⚠️ Skipped (pattern not matched): {filename}")
                continue

            prefix, channel_code, z_index = match.groups()

            # ✅ Remove trailing _ or - to prevent "__"
            prefix = prefix.rstrip("_-")

            if channel_code not in channel_map:
                print(f"⚠️ Unknown channel: {filename}")
                continue

            new_channel = channel_map[channel_code]
            new_name = f"{prefix}_{new_channel}_Z{z_index}.tif"
            new_path = os.path.join(subfolder_path, new_name)

            os.rename(old_path, new_path)
            print(f"✅ Renamed: {filename} → {new_name}")
# Out:
# Processing folder: Mouse3_0014.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0014_ch2_Z008.tif
# Processing folder: Mouse3_0008.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0008_ch1_Z009.tif
# Processing folder: Mouse3_0005.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0005_ch3_Z007.tif
# Processing folder: Mouse3_0000.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_ch1_Z009.tif
# Processing folder: Mouse3_0011.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0011_ch3_Z001.tif
# Processing folder: Mouse3_0007.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0007_ch3_Z008.tif
# Processing folder: Mouse3_0002.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0002_ch3_Z007.tif
# Processing folder: Mouse3_0013.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0013_ch2_Z008.tif
# Processing folder: Mouse3_0001.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0001_ch3_Z009.tif
# Processing folder: Mouse3_0010.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0010_ch3_Z012.tif
# Processing folder: Mouse3_0015.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0015_ch2_Z009.tif
# Processing folder: Mouse3_0009.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0009_ch1_Z008.tif
# Processing folder: Mouse3_0004.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0004_ch3_Z001.tif
# Processing folder: Mouse3_0003.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0003_ch3_Z001.tif
# Processing folder: Mouse3_0012.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch3_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0012_ch2_Z009.tif
# Processing folder: Mouse3_0006.tif.frames
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z007.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z006.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z012.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z004.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z010.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z011.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z005.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z001.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z002.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch1_Z003.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z008.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch2_Z009.tif
# ⚠️ Skipped (pattern not matched): Mouse3_0006_ch3_Z009.tif

# %% [markdown]
# #### Step3: Organize 800nm and 920nm into one folder

# %%
import os
import shutil
import re

# ========== USER PATH ==========
base_path = "/Users/xinyicai/Desktop/to_do/20251201_ExRai_Snrk_KO_TIFF/Mouse3"
analysis_root = os.path.join(base_path, "analysis")
os.makedirs(analysis_root, exist_ok=True)

# ========== TXT LASER READER ==========
def get_laser_wavelength(frames_folder_path):
    for file in os.listdir(frames_folder_path):
        if file.endswith(".txt"):
            txt_path = os.path.join(frames_folder_path, file)
            with open(txt_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            in_ch2 = False
            for line in lines:
                if "[Channel 2]" in line:
                    in_ch2 = True
                elif in_ch2 and "Laser Wavelength" in line:
                    match = re.search(r"(\d+)\s*\[nm\]", line)
                    if match:
                        return int(match.group(1))
                elif line.startswith("[Channel 3]"):
                    break
    return None


# ========== SCAN ALL FRAMES ==========
frames = []

for f in os.listdir(base_path):
    if f.endswith("tif.frames"):
        match = re.search(r"_(\d{4})\.tif", f)
        if not match:
            print(f"⚠️ Skipped (bad name): {f}")
            continue

        index = int(match.group(1))
        fpath = os.path.join(base_path, f)
        wl = get_laser_wavelength(fpath)

        print(f"Detected: {f} → {wl} nm")

        if wl not in [800, 920]:
            print(f"⚠️ Unknown wavelength, skipped: {f}")
            continue

        frames.append((index, f, wl))

frames.sort()


# ========== BUFFER-BASED VIEW BUILDER ==========
buffer = {}
view_counter = 1

for index, folder, wl in frames:
    buffer[wl] = folder
    print(f"Buffered: {folder} → {wl} nm")

    # ✅ Only create view when BOTH lasers exist
    if 800 in buffer and 920 in buffer:
        view_folder = os.path.join(analysis_root, f"view{view_counter}")
        os.makedirs(view_folder, exist_ok=True)

        print(f"\n✅ Creating view{view_counter}")
        print(f"   800 → {buffer[800]}")
        print(f"   920 → {buffer[920]}")

        for wl_used in [800, 920]:
            src_folder = os.path.join(base_path, buffer[wl_used])

            for fname in os.listdir(src_folder):
            
                # ✅ Match anything that ends with _ch2_Z###.tif
                z_match = re.search(r"_ch2_(Z\d+\.tif)$", fname)
                if not z_match:
                    continue
            
                src_path = os.path.join(src_folder, fname)
            
                z_part = z_match.group(1)   # Z001.tif
                new_name = f"{wl_used}_ch2_{z_part}"
                dst_path = os.path.join(view_folder, new_name)
            
                if os.path.exists(dst_path):
                    print(f"⚠️ Overwrite blocked: {dst_path}")
                    continue
            
                shutil.copyfile(src_path, dst_path)
                print(f"✅ Copied → {new_name}")


        view_counter += 1
        buffer.clear()


# ========== LEFTOVER WARNING ==========
if buffer:
    print("⚠️ Leftover unpaired frame(s) after last view:")
    for wl, folder in buffer.items():
        print(f"   {wl} → {folder}")
# Out:
# Detected: Mouse3_0014.tif.frames → 920 nm
# Detected: Mouse3_0008.tif.frames → 920 nm
# Detected: Mouse3_0005.tif.frames → 800 nm
# Detected: Mouse3_0000.tif.frames → 920 nm
# Detected: Mouse3_0011.tif.frames → 800 nm
# Detected: Mouse3_0007.tif.frames → 800 nm
# Detected: Mouse3_0002.tif.frames → 920 nm
# Detected: Mouse3_0013.tif.frames → 800 nm
# Detected: Mouse3_0001.tif.frames → 800 nm
# Detected: Mouse3_0010.tif.frames → 920 nm
# Detected: Mouse3_0015.tif.frames → 800 nm
# Detected: Mouse3_0009.tif.frames → 800 nm
# Detected: Mouse3_0004.tif.frames → 920 nm
# Detected: Mouse3_0003.tif.frames → 800 nm
# Detected: Mouse3_0012.tif.frames → 920 nm
# Detected: Mouse3_0006.tif.frames → 920 nm
# Buffered: Mouse3_0000.tif.frames → 920 nm
# Buffered: Mouse3_0001.tif.frames → 800 nm
#
# ✅ Creating view1
#    800 → Mouse3_0001.tif.frames
#    920 → Mouse3_0000.tif.frames
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z012.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z001.tif
# Buffered: Mouse3_0002.tif.frames → 920 nm
# Buffered: Mouse3_0003.tif.frames → 800 nm
#
# ✅ Creating view2
#    800 → Mouse3_0003.tif.frames
#    920 → Mouse3_0002.tif.frames
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z007.tif
# Buffered: Mouse3_0004.tif.frames → 920 nm
# Buffered: Mouse3_0005.tif.frames → 800 nm
#
# ✅ Creating view3
#    800 → Mouse3_0005.tif.frames
#    920 → Mouse3_0004.tif.frames
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z001.tif
# Buffered: Mouse3_0006.tif.frames → 920 nm
# Buffered: Mouse3_0007.tif.frames → 800 nm
#
# ✅ Creating view4
#    800 → Mouse3_0007.tif.frames
#    920 → Mouse3_0006.tif.frames
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z012.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# Buffered: Mouse3_0008.tif.frames → 920 nm
# Buffered: Mouse3_0009.tif.frames → 800 nm
#
# ✅ Creating view5
#    800 → Mouse3_0009.tif.frames
#    920 → Mouse3_0008.tif.frames
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z012.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# Buffered: Mouse3_0010.tif.frames → 920 nm
# Buffered: Mouse3_0011.tif.frames → 800 nm
#
# ✅ Creating view6
#    800 → Mouse3_0011.tif.frames
#    920 → Mouse3_0010.tif.frames
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z012.tif
# ✅ Copied → 920_ch2_Z006.tif
# Buffered: Mouse3_0012.tif.frames → 920 nm
# Buffered: Mouse3_0013.tif.frames → 800 nm
#
# ✅ Creating view7
#    800 → Mouse3_0013.tif.frames
#    920 → Mouse3_0012.tif.frames
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z012.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z008.tif
# ✅ Copied → 920_ch2_Z009.tif
# Buffered: Mouse3_0014.tif.frames → 920 nm
# Buffered: Mouse3_0015.tif.frames → 800 nm
#
# ✅ Creating view8
#    800 → Mouse3_0015.tif.frames
#    920 → Mouse3_0014.tif.frames
# ✅ Copied → 800_ch2_Z010.tif
# ✅ Copied → 800_ch2_Z004.tif
# ✅ Copied → 800_ch2_Z005.tif
# ✅ Copied → 800_ch2_Z011.tif
# ✅ Copied → 800_ch2_Z007.tif
# ✅ Copied → 800_ch2_Z012.tif
# ✅ Copied → 800_ch2_Z006.tif
# ✅ Copied → 800_ch2_Z002.tif
# ✅ Copied → 800_ch2_Z003.tif
# ✅ Copied → 800_ch2_Z001.tif
# ✅ Copied → 800_ch2_Z008.tif
# ✅ Copied → 800_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z003.tif
# ✅ Copied → 920_ch2_Z002.tif
# ✅ Copied → 920_ch2_Z001.tif
# ✅ Copied → 920_ch2_Z011.tif
# ✅ Copied → 920_ch2_Z005.tif
# ✅ Copied → 920_ch2_Z004.tif
# ✅ Copied → 920_ch2_Z010.tif
# ✅ Copied → 920_ch2_Z006.tif
# ✅ Copied → 920_ch2_Z007.tif
# ✅ Copied → 920_ch2_Z009.tif
# ✅ Copied → 920_ch2_Z008.tif
